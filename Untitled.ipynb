# %%
# !pip install scikit-learn

# %%
from sklearn import tree

# %%
features=[
    [150,0],
    [170,0],
    [130,1],
    [120,1],
]

# %%
labels=["apple","apple","orange","orange"]

# %%
clf= tree.DecisionTreeClassifier()
clf=clf.fit(features,labels)

# %%
pre_01=clf.predict([[160,0]])
pre_02=clf.predict([[130,1]])

# %%
print(f"The fruit is {pre_01[0]}")
print(f"The fruit is {pre_02[0]}")
# Out:
# The fruit is apple
# The fruit is orange

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
 
plt.figure(figsize=(10,6))
plot_tree(clf, feature_names=["weight", "color"], class_names=["apple", "orange"], filled=True)
plt.show()

# %%
from sklearn.tree import plot_tree

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(11,15))

# %%
plot_tree(clf,feature_names=["weight","color"],class_names=["apple","orange"],filled=True)
# Out:
# [Text(0.5, 0.75, 'color <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = apple'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = apple'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = orange'),
#  Text(0.625, 0.5, '  False')]
